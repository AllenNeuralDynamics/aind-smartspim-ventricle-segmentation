# %%
import numpy as np
import torch
import cv2
import os
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor
import zarr
from pathlib import Path
import numpy as np

BASE_PATH = Path("/scratch/")

mask_path = BASE_PATH.joinpath("693196-VS_73_sasha_smoothed.zarr")
img_path = BASE_PATH.joinpath("scaled_693196.zarr")
# points_path = BASE_PATH.joinpath("sam2_points_693196.npy")
# bboxs_path = BASE_PATH.joinpath("sam2_bboxs_693196.npy")

mask = zarr.load(mask_path).astype(np.uint8)
img = zarr.load(img_path)
# points = np.load(points_path)
# bboxs = np.load(bboxs_path)

print(img.shape, mask.shape, img.dtype, mask.dtype)#, points.dtype, points.shape)
# Out:
# /opt/conda/lib/python3.10/site-packages/sam2/modeling/sam/transformer.py:23: UserWarning: Flash Attention is disabled as it requires a GPU with Ampere (8.0) CUDA capability.
#   OLD_GPU, USE_FLASH_ATTN, MATH_KERNEL_ON = get_sdpa_settings()
# (458, 1282, 929) (458, 1282, 929) float16 uint8

# %%
from scipy.ndimage import zoom, distance_transform_edt
import matplotlib.pyplot as plt
from pathlib import Path
from skimage.measure import regionprops, label
import heapq
from scipy.spatial.distance import cdist

def compute_dt_per_slice(mask):
    distance_transform = mask.copy().astype(np.float32)

    for i, curr_msk in enumerate(mask):
        if np.count_nonzero(curr_msk):
            distance_transform[i] = distance_transform_edt(curr_msk).astype(np.float32)

    return distance_transform

# %matplotlib inline

def get_points_in_distance(points, d):
    """
    Sample points from the given set such that each selected point is at least distance `d` away
    from all previously selected points.

    Parameters:
    - points: A NumPy array of shape (n, m), where n is the number of points and m is the dimensionality.
    - d: Minimum distance between selected points.

    Returns:
    - A NumPy array of the selected points.
    """
    # Convert points to a NumPy array if not already
    points = np.array(points)

    # List to store the selected points
    selected_points = [points[0]]

    # Iterate over all points
    for idx, point in enumerate(points[1:]):
        # If no points have been selected yet, select the first one
        if not selected_points:
            selected_points.append(point)
        else:
            # Compute pairwise distances between the new point and the already selected points
            distances = cdist([point], selected_points)

            # If the new point is at least distance `d` away from all selected points, select it
            if np.all(distances >= d):
                selected_points.append(point)

    return np.array(selected_points)

def sort_points_by_heatmap(heatmap, points):
    """
    Sort points based on the values in the heatmap.

    Parameters:
    - heatmap: A 2D NumPy array representing the heatmap.
    - points: A NumPy array of shape (n, 2), where each row is a point with (row_index, column_index).

    Returns:
    - A sorted NumPy array of points based on their values in the heatmap.
    """
    # print(heatmap.shape, points)
    # Extract heatmap values for each point
    heatmap_values = heatmap[points[:, 0], points[:, 1]]

    # Sort points based on the heatmap values
    sorted_indices = np.argsort(heatmap_values)[::-1]
    sorted_points = points[sorted_indices]

    return sorted_points, heatmap_values[sorted_indices]

def get_sparsed_points(mask, distance_transform, n_points=5, min_point_distance=10.0):
    points = []

    for mask_index, slice_mask in enumerate(mask):
        counted_non_zero = np.count_nonzero(slice_mask)
        if counted_non_zero > 80:

            labeled_slice_mask, num_regions = label(slice_mask, return_num=True)
            
            for region_label in range(1, num_regions + 1):
                region_mask = labeled_slice_mask == region_label
                
                region_coords = np.column_stack(np.where(region_mask))

                region_coords, distance_transform_sorted = sort_points_by_heatmap(
                    distance_transform[mask_index], 
                    region_coords
                )
                
                picked_points = get_points_in_distance(region_coords, d=min_point_distance)

                picked_points = np.insert(picked_points, 0, mask_index, axis=1)
                points.append(picked_points[:n_points].copy())

    points_filtered = np.unique(np.concatenate(points, axis=0), axis=0)
    return points_filtered

# %%
def create_slices(
    brain_id,
    image_data,
    mask_data,
    output_images,
    output_masks,
    output_points,
    n_points=5,
    min_point_distance=10.0,
):
    """Gotta refactor, too many params"""
    output_images = Path(output_images)
    output_masks = Path(output_masks)
    output_points = Path(output_points)
    points = []
    
    if not output_images.exists():
        output_images.mkdir(parents=True, exist_ok=True)

    if not output_masks.exists():
        output_masks.mkdir(parents=True, exist_ok=True)

    if not output_points.exists():
        output_points.mkdir(parents=True, exist_ok=True)

    idx_range = range(mask_data.shape[0])
    generated_idxs = []

    for mask_idx in idx_range:

        curr_mask = mask_data[mask_idx]
        non_zero = np.count_nonzero(curr_mask)

        if non_zero > 100:
            print(f"Generating slice for slice: {mask_idx}")
            curr_slice = image_data[mask_idx].astype(np.float32)
            scaling_factor = (1024 / curr_slice.shape[0], 1024 / curr_slice.shape[1])

            curr_slice = zoom(curr_slice, scaling_factor, order=3)
            min_val = np.min(curr_slice)
            max_val = np.max(curr_slice)
            
            curr_slice = (curr_slice - min_val) / (max_val - min_val)
            curr_slice = (curr_slice * 255).astype(np.float16)

            # Creating mask
            curr_mask = zoom(curr_mask, scaling_factor, order=0).astype(np.uint8)

            # Labeling binary areas
            labeled_curr_mask, num_regions = label(curr_mask, return_num=True)
            msk_dt = distance_transform_edt(curr_mask).astype(np.float32)

            mask_points = []
            # Going through regions to get the points based on edt

            for region_label in range(1, num_regions + 1):
                region_mask = labeled_curr_mask == region_label

                region_coords = np.column_stack(np.where(region_mask))

                region_coords, distance_transform_sorted = sort_points_by_heatmap(
                    msk_dt, region_coords
                )

                picked_points = get_points_in_distance(
                    region_coords, d=min_point_distance
                )
                mask_points.append(picked_points[:n_points].copy())

            mask_points = np.concatenate(mask_points, axis=0).astype(np.uint32)
            mask_points = np.insert(mask_points, 0, mask_idx, axis=1)

            if mask_points.shape[0]:
                np.save(
                    str(
                        output_images.joinpath(
                            f"smartspim_{brain_id}_vs_{mask_idx}.npy"
                        )
                    ),
                    curr_slice,
                )
                np.save(
                    str(
                        output_masks.joinpath(f"smartspim_{brain_id}_vs_{mask_idx}.npy")
                    ),
                    curr_mask,
                )
                points.append(mask_points.copy())
                generated_idxs.append(mask_idx)
                
                # np.save(
                #     str(
                #         output_points.joinpath(
                #             f"smartspim_{brain_id}_vs_{mask_idx}.npy"
                #         )
                #     ),
                #     mask_points,
                # )

            else:
                print(
                    f"Not saving slice {mask_idx} since there are no points: {mask_points.shape}"
                )
                raise ValueError

    points = np.concatenate(points, axis=0).astype(np.uint16)
    np.save(
        str(
            output_points.joinpath(
                f"smartspim_{brain_id}_vs_pts.npy"
            )
        ),
        points,
    )
    return generated_idxs

# %%
dataset_path = Path("/scratch/ventricle_dataset")

idxs = create_slices(
    brain_id="693196",
    image_data=img,
    mask_data=mask,
    output_images=dataset_path.joinpath('train/images'),
    output_masks=dataset_path.joinpath('train/labels'),
    output_points=dataset_path.joinpath('train/points'),
    n_points=1,
    min_point_distance=10.0
)
# Out:
# Generating slice for slice: 73
# Generating slice for slice: 74
# Generating slice for slice: 75
# Generating slice for slice: 76
# Generating slice for slice: 77
# Generating slice for slice: 78
# Generating slice for slice: 79
# Generating slice for slice: 80
# Generating slice for slice: 81
# Generating slice for slice: 82
# Generating slice for slice: 83
# Generating slice for slice: 84
# Generating slice for slice: 85
# Generating slice for slice: 86
# Generating slice for slice: 87
# Generating slice for slice: 88
# Generating slice for slice: 89
# Generating slice for slice: 90
# Generating slice for slice: 91
# Generating slice for slice: 92
# Generating slice for slice: 93
# Generating slice for slice: 94
# Generating slice for slice: 95
# Generating slice for slice: 96
# Generating slice for slice: 97
# Generating slice for slice: 98
# Generating slice for slice: 99
# Generating slice for slice: 100
# Generating slice for slice: 101
# Generating slice for slice: 102
# Generating slice for slice: 103
# Generating slice for slice: 104
# Generating slice for slice: 105
# Generating slice for slice: 106
# Generating slice for slice: 107
# Generating slice for slice: 108
# Generating slice for slice: 109
# Generating slice for slice: 110
# Generating slice for slice: 111
# Generating slice for slice: 112
# Generating slice for slice: 113
# Generating slice for slice: 114
# Generating slice for slice: 115
# Generating slice for slice: 116
# Generating slice for slice: 117
# Generating slice for slice: 118
# Generating slice for slice: 119
# Generating slice for slice: 120
# Generating slice for slice: 121
# Generating slice for slice: 122
# Generating slice for slice: 123
# Generating slice for slice: 124
# Generating slice for slice: 125
# Generating slice for slice: 126
# Generating slice for slice: 127
# Generating slice for slice: 128
# Generating slice for slice: 129
# Generating slice for slice: 130
# Generating slice for slice: 131
# Generating slice for slice: 132
# Generating slice for slice: 133
# Generating slice for slice: 134
# Generating slice for slice: 135
# Generating slice for slice: 136
# Generating slice for slice: 137
# Generating slice for slice: 138
# Generating slice for slice: 139
# Generating slice for slice: 140
# Generating slice for slice: 141
# Generating slice for slice: 142
# Generating slice for slice: 143
# Generating slice for slice: 144
# Generating slice for slice: 145
# Generating slice for slice: 146
# Generating slice for slice: 147
# Generating slice for slice: 148
# Generating slice for slice: 149
# Generating slice for slice: 150
# Generating slice for slice: 151
# Generating slice for slice: 152
# Generating slice for slice: 153
# Generating slice for slice: 154
# Generating slice for slice: 155
# Generating slice for slice: 156
# Generating slice for slice: 157
# Generating slice for slice: 158
# Generating slice for slice: 159
# Generating slice for slice: 160
# Generating slice for slice: 161
# Generating slice for slice: 162
# Generating slice for slice: 163
# Generating slice for slice: 164
# Generating slice for slice: 165
# Generating slice for slice: 166
# Generating slice for slice: 167
# Generating slice for slice: 168
# Generating slice for slice: 169
# Generating slice for slice: 170
# Generating slice for slice: 171
# Generating slice for slice: 172
# Generating slice for slice: 173
# Generating slice for slice: 174
# Generating slice for slice: 175
# Generating slice for slice: 176
# Generating slice for slice: 177
# Generating slice for slice: 178
# Generating slice for slice: 179
# Generating slice for slice: 180
# Generating slice for slice: 181
# Generating slice for slice: 182
# Generating slice for slice: 183
# Generating slice for slice: 184
# Generating slice for slice: 185
# Generating slice for slice: 186
# Generating slice for slice: 187
# Generating slice for slice: 188
# Generating slice for slice: 189
# Generating slice for slice: 190
# Generating slice for slice: 191
# Generating slice for slice: 192
# Generating slice for slice: 193
# Generating slice for slice: 194
# Generating slice for slice: 195
# Generating slice for slice: 196
# Generating slice for slice: 197
# Generating slice for slice: 198
# Generating slice for slice: 199
# Generating slice for slice: 200
# Generating slice for slice: 201
# Generating slice for slice: 202
# Generating slice for slice: 203
# Generating slice for slice: 204
# Generating slice for slice: 205
# Generating slice for slice: 206
# Generating slice for slice: 207
# Generating slice for slice: 208
# Generating slice for slice: 209
# Generating slice for slice: 210
# Generating slice for slice: 211
# Generating slice for slice: 212
# Generating slice for slice: 213
# Generating slice for slice: 214
# Generating slice for slice: 215
# Generating slice for slice: 216
# Generating slice for slice: 217
# Generating slice for slice: 218
# Generating slice for slice: 219
# Generating slice for slice: 220
# Generating slice for slice: 221
# Generating slice for slice: 222
# Generating slice for slice: 223
# Generating slice for slice: 224
# Generating slice for slice: 225
# Generating slice for slice: 226
# Generating slice for slice: 227
# Generating slice for slice: 228
# Generating slice for slice: 229
# Generating slice for slice: 230
# Generating slice for slice: 231
# Generating slice for slice: 232
# Generating slice for slice: 233
# Generating slice for slice: 234
# Generating slice for slice: 235
# Generating slice for slice: 236
# Generating slice for slice: 237
# Generating slice for slice: 238
# Generating slice for slice: 239
# Generating slice for slice: 240
# Generating slice for slice: 241
# Generating slice for slice: 242
# Generating slice for slice: 243
# Generating slice for slice: 244
# Generating slice for slice: 245
# Generating slice for slice: 246
# Generating slice for slice: 247
# Generating slice for slice: 248
# Generating slice for slice: 249
# Generating slice for slice: 250
# Generating slice for slice: 251
# Generating slice for slice: 252
# Generating slice for slice: 253
# Generating slice for slice: 254
# Generating slice for slice: 255
# Generating slice for slice: 256
# Generating slice for slice: 257
# Generating slice for slice: 258
# Generating slice for slice: 259
# Generating slice for slice: 260
# Generating slice for slice: 261
# Generating slice for slice: 262
# Generating slice for slice: 263
# Generating slice for slice: 264
# Generating slice for slice: 265
# Generating slice for slice: 266
# Generating slice for slice: 267
# Generating slice for slice: 268
# Generating slice for slice: 269
# Generating slice for slice: 270
# Generating slice for slice: 271
# Generating slice for slice: 272
# Generating slice for slice: 273
# Generating slice for slice: 274
# Generating slice for slice: 275
# Generating slice for slice: 276
# Generating slice for slice: 277
# Generating slice for slice: 278
# Generating slice for slice: 279
# Generating slice for slice: 280
# Generating slice for slice: 281
# Generating slice for slice: 282
# Generating slice for slice: 283
# Generating slice for slice: 284
# Generating slice for slice: 285
# Generating slice for slice: 286
# Generating slice for slice: 287
# Generating slice for slice: 288
# Generating slice for slice: 289
# Generating slice for slice: 290
# Generating slice for slice: 291
# Generating slice for slice: 292
# Generating slice for slice: 293
# Generating slice for slice: 294
# Generating slice for slice: 295
# Generating slice for slice: 296
# Generating slice for slice: 297
# Generating slice for slice: 298
# Generating slice for slice: 299
# Generating slice for slice: 300
# Generating slice for slice: 301
# Generating slice for slice: 302
# Generating slice for slice: 303
# Generating slice for slice: 304
# Generating slice for slice: 305
# Generating slice for slice: 306
# Generating slice for slice: 307
# Generating slice for slice: 308
# Generating slice for slice: 309
# Generating slice for slice: 310
# Generating slice for slice: 311
# Generating slice for slice: 312
# Generating slice for slice: 313
# Generating slice for slice: 314
# Generating slice for slice: 315
# Generating slice for slice: 316
# Generating slice for slice: 317
# Generating slice for slice: 318
# Generating slice for slice: 319
# Generating slice for slice: 320
# Generating slice for slice: 321
# Generating slice for slice: 322
# Generating slice for slice: 323
# Generating slice for slice: 324
# Generating slice for slice: 325
# Generating slice for slice: 326
# Generating slice for slice: 327
# Generating slice for slice: 328
# Generating slice for slice: 329
# Generating slice for slice: 330
# Generating slice for slice: 331
# Generating slice for slice: 332
# Generating slice for slice: 333
# Generating slice for slice: 334
# Generating slice for slice: 335
# Generating slice for slice: 336
# Generating slice for slice: 337
# Generating slice for slice: 338
# Generating slice for slice: 339
# Generating slice for slice: 340
# Generating slice for slice: 341
# Generating slice for slice: 342
# Generating slice for slice: 343
# Generating slice for slice: 344
# Generating slice for slice: 345
# Generating slice for slice: 346
# Generating slice for slice: 347
# Generating slice for slice: 348
# Generating slice for slice: 349
# Generating slice for slice: 350
# Generating slice for slice: 351
# Generating slice for slice: 352
# Generating slice for slice: 353
# Generating slice for slice: 354
# Generating slice for slice: 355
# Generating slice for slice: 356
# Generating slice for slice: 357
# Generating slice for slice: 358
# Generating slice for slice: 359
# Generating slice for slice: 360
# Generating slice for slice: 361
# Generating slice for slice: 362
# Generating slice for slice: 363
# Generating slice for slice: 364
# Generating slice for slice: 365
# Generating slice for slice: 366
# Generating slice for slice: 367
# Generating slice for slice: 368
# Generating slice for slice: 369
# Generating slice for slice: 370
# Generating slice for slice: 371
# Generating slice for slice: 372
# Generating slice for slice: 373
# Generating slice for slice: 374
# Generating slice for slice: 375
# Generating slice for slice: 376
# Generating slice for slice: 377
# Generating slice for slice: 378
# Generating slice for slice: 379
# Generating slice for slice: 380
# Generating slice for slice: 381
# Generating slice for slice: 382
# Generating slice for slice: 383
# Generating slice for slice: 384
# Generating slice for slice: 385
# Generating slice for slice: 386
# Generating slice for slice: 387
# Generating slice for slice: 388
# Generating slice for slice: 389
# Generating slice for slice: 390
# Generating slice for slice: 391
# Generating slice for slice: 392
# Generating slice for slice: 393
# Generating slice for slice: 394
# Generating slice for slice: 395
# Generating slice for slice: 396
# Generating slice for slice: 397
# Generating slice for slice: 398
# Generating slice for slice: 399
# Generating slice for slice: 400
# Generating slice for slice: 401
# Generating slice for slice: 402
# Generating slice for slice: 403
# Generating slice for slice: 404
# Generating slice for slice: 405
# Generating slice for slice: 406
# Generating slice for slice: 407
# Generating slice for slice: 408
# Generating slice for slice: 409
# Generating slice for slice: 410
# Generating slice for slice: 411
# Generating slice for slice: 412
# Generating slice for slice: 413
# Generating slice for slice: 414
# Generating slice for slice: 415
# Generating slice for slice: 416
# Generating slice for slice: 417
# Generating slice for slice: 418
# Generating slice for slice: 419
# Generating slice for slice: 420
# Generating slice for slice: 421
# Generating slice for slice: 422
# Generating slice for slice: 423
# Generating slice for slice: 424
# Generating slice for slice: 425
# Generating slice for slice: 426
# Generating slice for slice: 427
# Generating slice for slice: 428
# Generating slice for slice: 429
# Generating slice for slice: 430
# Generating slice for slice: 431
# Generating slice for slice: 432
# Generating slice for slice: 433
# Generating slice for slice: 434
# Generating slice for slice: 435
# Generating slice for slice: 436
# Generating slice for slice: 437
# Generating slice for slice: 438
# Generating slice for slice: 439
# Generating slice for slice: 440
# Generating slice for slice: 441
# Generating slice for slice: 442
# Generating slice for slice: 443
# Generating slice for slice: 444
# Generating slice for slice: 445
# Generating slice for slice: 446
# Generating slice for slice: 447
# Generating slice for slice: 448
# Generating slice for slice: 449
# Generating slice for slice: 450
# Generating slice for slice: 451
# Generating slice for slice: 452
# Generating slice for slice: 453
# Generating slice for slice: 454
# Generating slice for slice: 455
# Generating slice for slice: 456
# Generating slice for slice: 457

# %%
import numpy as np
# BASE_PATH_POINTS = Path("/scratch/ventricle_dataset/train/points")
points = np.load("/scratch/ventricle_dataset/train/points/smartspim_693196_vs_pts.npy")

for i in idxs:
    c = points[points[:, 0]==i]
    if not c.shape[0]:
        print(f"Problem with {i}")
    else:
        print(f"Slice {i} has {c.shape}")
# Out:
# Slice 73 has (1, 3)
# Slice 74 has (1, 3)
# Slice 75 has (1, 3)
# Slice 76 has (1, 3)
# Slice 77 has (1, 3)
# Slice 78 has (1, 3)
# Slice 79 has (1, 3)
# Slice 80 has (1, 3)
# Slice 81 has (1, 3)
# Slice 82 has (1, 3)
# Slice 83 has (1, 3)
# Slice 84 has (1, 3)
# Slice 85 has (1, 3)
# Slice 86 has (1, 3)
# Slice 87 has (1, 3)
# Slice 88 has (1, 3)
# Slice 89 has (1, 3)
# Slice 90 has (1, 3)
# Slice 91 has (1, 3)
# Slice 92 has (1, 3)
# Slice 93 has (1, 3)
# Slice 94 has (1, 3)
# Slice 95 has (1, 3)
# Slice 96 has (1, 3)
# Slice 97 has (1, 3)
# Slice 98 has (1, 3)
# Slice 99 has (1, 3)
# Slice 100 has (1, 3)
# Slice 101 has (1, 3)
# Slice 102 has (3, 3)
# Slice 103 has (2, 3)
# Slice 104 has (2, 3)
# Slice 105 has (1, 3)
# Slice 106 has (2, 3)
# Slice 107 has (2, 3)
# Slice 108 has (2, 3)
# Slice 109 has (2, 3)
# Slice 110 has (2, 3)
# Slice 111 has (2, 3)
# Slice 112 has (2, 3)
# Slice 113 has (3, 3)
# Slice 114 has (2, 3)
# Slice 115 has (4, 3)
# Slice 116 has (5, 3)
# Slice 117 has (5, 3)
# Slice 118 has (3, 3)
# Slice 119 has (3, 3)
# Slice 120 has (3, 3)
# Slice 121 has (3, 3)
# Slice 122 has (3, 3)
# Slice 123 has (3, 3)
# Slice 124 has (3, 3)
# Slice 125 has (3, 3)
# Slice 126 has (3, 3)
# Slice 127 has (3, 3)
# Slice 128 has (3, 3)
# Slice 129 has (3, 3)
# Slice 130 has (3, 3)
# Slice 131 has (3, 3)
# Slice 132 has (3, 3)
# Slice 133 has (4, 3)
# Slice 134 has (4, 3)
# Slice 135 has (5, 3)
# Slice 136 has (6, 3)
# Slice 137 has (3, 3)
# Slice 138 has (3, 3)
# Slice 139 has (3, 3)
# Slice 140 has (3, 3)
# Slice 141 has (3, 3)
# Slice 142 has (4, 3)
# Slice 143 has (6, 3)
# Slice 144 has (4, 3)
# Slice 145 has (3, 3)
# Slice 146 has (5, 3)
# Slice 147 has (5, 3)
# Slice 148 has (6, 3)
# Slice 149 has (8, 3)
# Slice 150 has (5, 3)
# Slice 151 has (4, 3)
# Slice 152 has (4, 3)
# Slice 153 has (4, 3)
# Slice 154 has (8, 3)
# Slice 155 has (6, 3)
# Slice 156 has (5, 3)
# Slice 157 has (5, 3)
# Slice 158 has (4, 3)
# Slice 159 has (5, 3)
# Slice 160 has (5, 3)
# Slice 161 has (6, 3)
# Slice 162 has (6, 3)
# Slice 163 has (4, 3)
# Slice 164 has (4, 3)
# Slice 165 has (5, 3)
# Slice 166 has (6, 3)
# Slice 167 has (6, 3)
# Slice 168 has (9, 3)
# Slice 169 has (8, 3)
# Slice 170 has (6, 3)
# Slice 171 has (9, 3)
# Slice 172 has (7, 3)
# Slice 173 has (5, 3)
# Slice 174 has (5, 3)
# Slice 175 has (6, 3)
# Slice 176 has (5, 3)
# Slice 177 has (6, 3)
# Slice 178 has (7, 3)
# Slice 179 has (7, 3)
# Slice 180 has (8, 3)
# Slice 181 has (6, 3)
# Slice 182 has (6, 3)
# Slice 183 has (6, 3)
# Slice 184 has (6, 3)
# Slice 185 has (6, 3)
# Slice 186 has (7, 3)
# Slice 187 has (7, 3)
# Slice 188 has (9, 3)
# Slice 189 has (9, 3)
# Slice 190 has (10, 3)
# Slice 191 has (9, 3)
# Slice 192 has (13, 3)
# Slice 193 has (15, 3)
# Slice 194 has (13, 3)
# Slice 195 has (11, 3)
# Slice 196 has (12, 3)
# Slice 197 has (12, 3)
# Slice 198 has (13, 3)
# Slice 199 has (12, 3)
# Slice 200 has (12, 3)
# Slice 201 has (10, 3)
# Slice 202 has (9, 3)
# Slice 203 has (14, 3)
# Slice 204 has (14, 3)
# Slice 205 has (13, 3)
# Slice 206 has (13, 3)
# Slice 207 has (16, 3)
# Slice 208 has (13, 3)
# Slice 209 has (11, 3)
# Slice 210 has (11, 3)
# Slice 211 has (10, 3)
# Slice 212 has (11, 3)
# Slice 213 has (10, 3)
# Slice 214 has (11, 3)
# Slice 215 has (10, 3)
# Slice 216 has (8, 3)
# Slice 217 has (8, 3)
# Slice 218 has (8, 3)
# Slice 219 has (11, 3)
# Slice 220 has (14, 3)
# Slice 221 has (12, 3)
# Slice 222 has (11, 3)
# Slice 223 has (11, 3)
# Slice 224 has (11, 3)
# Slice 225 has (12, 3)
# Slice 226 has (14, 3)
# Slice 227 has (11, 3)
# Slice 228 has (12, 3)
# Slice 229 has (14, 3)
# Slice 230 has (15, 3)
# Slice 231 has (12, 3)
# Slice 232 has (11, 3)
# Slice 233 has (10, 3)
# Slice 234 has (11, 3)
# Slice 235 has (11, 3)
# Slice 236 has (11, 3)
# Slice 237 has (12, 3)
# Slice 238 has (11, 3)
# Slice 239 has (11, 3)
# Slice 240 has (8, 3)
# Slice 241 has (8, 3)
# Slice 242 has (10, 3)
# Slice 243 has (10, 3)
# Slice 244 has (9, 3)
# Slice 245 has (11, 3)
# Slice 246 has (10, 3)
# Slice 247 has (9, 3)
# Slice 248 has (9, 3)
# Slice 249 has (10, 3)
# Slice 250 has (11, 3)
# Slice 251 has (9, 3)
# Slice 252 has (7, 3)
# Slice 253 has (8, 3)
# Slice 254 has (8, 3)
# Slice 255 has (7, 3)
# Slice 256 has (7, 3)
# Slice 257 has (7, 3)
# Slice 258 has (7, 3)
# Slice 259 has (7, 3)
# Slice 260 has (7, 3)
# Slice 261 has (7, 3)
# Slice 262 has (7, 3)
# Slice 263 has (7, 3)
# Slice 264 has (8, 3)
# Slice 265 has (8, 3)
# Slice 266 has (8, 3)
# Slice 267 has (8, 3)
# Slice 268 has (9, 3)
# Slice 269 has (8, 3)
# Slice 270 has (9, 3)
# Slice 271 has (9, 3)
# Slice 272 has (8, 3)
# Slice 273 has (9, 3)
# Slice 274 has (10, 3)
# Slice 275 has (10, 3)
# Slice 276 has (11, 3)
# Slice 277 has (10, 3)
# Slice 278 has (9, 3)
# Slice 279 has (10, 3)
# Slice 280 has (8, 3)
# Slice 281 has (9, 3)
# Slice 282 has (8, 3)
# Slice 283 has (7, 3)
# Slice 284 has (7, 3)
# Slice 285 has (7, 3)
# Slice 286 has (8, 3)
# Slice 287 has (7, 3)
# Slice 288 has (7, 3)
# Slice 289 has (7, 3)
# Slice 290 has (7, 3)
# Slice 291 has (8, 3)
# Slice 292 has (7, 3)
# Slice 293 has (6, 3)
# Slice 294 has (7, 3)
# Slice 295 has (9, 3)
# Slice 296 has (6, 3)
# Slice 297 has (6, 3)
# Slice 298 has (7, 3)
# Slice 299 has (9, 3)
# Slice 300 has (7, 3)
# Slice 301 has (7, 3)
# Slice 302 has (6, 3)
# Slice 303 has (7, 3)
# Slice 304 has (9, 3)
# Slice 305 has (12, 3)
# Slice 306 has (10, 3)
# Slice 307 has (9, 3)
# Slice 308 has (8, 3)
# Slice 309 has (8, 3)
# Slice 310 has (9, 3)
# Slice 311 has (13, 3)
# Slice 312 has (11, 3)
# Slice 313 has (13, 3)
# Slice 314 has (13, 3)
# Slice 315 has (15, 3)
# Slice 316 has (14, 3)
# Slice 317 has (15, 3)
# Slice 318 has (16, 3)
# Slice 319 has (16, 3)
# Slice 320 has (20, 3)
# Slice 321 has (10, 3)
# Slice 322 has (14, 3)
# Slice 323 has (9, 3)
# Slice 324 has (11, 3)
# Slice 325 has (13, 3)
# Slice 326 has (12, 3)
# Slice 327 has (13, 3)
# Slice 328 has (11, 3)
# Slice 329 has (10, 3)
# Slice 330 has (9, 3)
# Slice 331 has (9, 3)
# Slice 332 has (8, 3)
# Slice 333 has (10, 3)
# Slice 334 has (11, 3)
# Slice 335 has (11, 3)
# Slice 336 has (15, 3)
# Slice 337 has (17, 3)
# Slice 338 has (18, 3)
# Slice 339 has (15, 3)
# Slice 340 has (17, 3)
# Slice 341 has (15, 3)
# Slice 342 has (13, 3)
# Slice 343 has (13, 3)
# Slice 344 has (12, 3)
# Slice 345 has (11, 3)
# Slice 346 has (10, 3)
# Slice 347 has (9, 3)
# Slice 348 has (10, 3)
# Slice 349 has (9, 3)
# Slice 350 has (9, 3)
# Slice 351 has (13, 3)
# Slice 352 has (8, 3)
# Slice 353 has (9, 3)
# Slice 354 has (9, 3)
# Slice 355 has (8, 3)
# Slice 356 has (8, 3)
# Slice 357 has (9, 3)
# Slice 358 has (10, 3)
# Slice 359 has (8, 3)
# Slice 360 has (7, 3)
# Slice 361 has (6, 3)
# Slice 362 has (5, 3)
# Slice 363 has (6, 3)
# Slice 364 has (5, 3)
# Slice 365 has (5, 3)
# Slice 366 has (4, 3)
# Slice 367 has (4, 3)
# Slice 368 has (4, 3)
# Slice 369 has (4, 3)
# Slice 370 has (4, 3)
# Slice 371 has (3, 3)
# Slice 372 has (3, 3)
# Slice 373 has (3, 3)
# Slice 374 has (3, 3)
# Slice 375 has (3, 3)
# Slice 376 has (5, 3)
# Slice 377 has (5, 3)
# Slice 378 has (6, 3)
# Slice 379 has (6, 3)
# Slice 380 has (6, 3)
# Slice 381 has (6, 3)
# Slice 382 has (5, 3)
# Slice 383 has (5, 3)
# Slice 384 has (5, 3)
# Slice 385 has (5, 3)
# Slice 386 has (5, 3)
# Slice 387 has (5, 3)
# Slice 388 has (5, 3)
# Slice 389 has (5, 3)
# Slice 390 has (5, 3)
# Slice 391 has (6, 3)
# Slice 392 has (6, 3)
# Slice 393 has (7, 3)
# Slice 394 has (5, 3)
# Slice 395 has (4, 3)
# Slice 396 has (4, 3)
# Slice 397 has (4, 3)
# Slice 398 has (6, 3)
# Slice 399 has (5, 3)
# Slice 400 has (7, 3)
# Slice 401 has (6, 3)
# Slice 402 has (6, 3)
# Slice 403 has (4, 3)
# Slice 404 has (4, 3)
# Slice 405 has (4, 3)
# Slice 406 has (4, 3)
# Slice 407 has (5, 3)
# Slice 408 has (8, 3)
# Slice 409 has (9, 3)
# Slice 410 has (11, 3)
# Slice 411 has (12, 3)
# Slice 412 has (11, 3)
# Slice 413 has (9, 3)
# Slice 414 has (10, 3)
# Slice 415 has (7, 3)
# Slice 416 has (6, 3)
# Slice 417 has (5, 3)
# Slice 418 has (5, 3)
# Slice 419 has (5, 3)
# Slice 420 has (5, 3)
# Slice 421 has (3, 3)
# Slice 422 has (4, 3)
# Slice 423 has (5, 3)
# Slice 424 has (3, 3)
# Slice 425 has (3, 3)
# Slice 426 has (3, 3)
# Slice 427 has (3, 3)
# Slice 428 has (3, 3)
# Slice 429 has (3, 3)
# Slice 430 has (4, 3)
# Slice 431 has (4, 3)
# Slice 432 has (4, 3)
# Slice 433 has (5, 3)
# Slice 434 has (3, 3)
# Slice 435 has (4, 3)
# Slice 436 has (3, 3)
# Slice 437 has (2, 3)
# Slice 438 has (2, 3)
# Slice 439 has (2, 3)
# Slice 440 has (1, 3)
# Slice 441 has (1, 3)
# Slice 442 has (1, 3)
# Slice 443 has (1, 3)
# Slice 444 has (1, 3)
# Slice 445 has (1, 3)
# Slice 446 has (1, 3)
# Slice 447 has (1, 3)
# Slice 448 has (1, 3)
# Slice 449 has (1, 3)
# Slice 450 has (1, 3)
# Slice 451 has (1, 3)
# Slice 452 has (1, 3)
# Slice 453 has (1, 3)
# Slice 454 has (1, 3)
# Slice 455 has (1, 3)
# Slice 456 has (1, 3)
# Slice 457 has (1, 3)

# %%
points.shape
# Out:
# (2596, 3)

# %%
# Out:
# array([], shape=(0, 3), dtype=uint16)
